# %% [markdown]
# # Time-Series Modeling
#
# This lesson is adapted from Sean Abu:
#
# http://www.seanabu.com/2016/03/22/time-series-seasonal-ARIMA-model-in-python/
#
# With examples from Forecasting Principles and Practice, by Hyndman and Athanastopoulos:
#
# https://www.otexts.org/fpp
#
# The latter is an excellent text book and worth checking out.  I also recommend their fpp package for R, which provides some nice functionality to auto-select the order of an ARIMA model.
#
# ### Basics
#
# A time-series is a series of data points indexed in time order.  It is naturally one-dimensional, and for our purposes we will consider that all points are equally spaced.
#
# We may want to model time series for either inference (understanding statistical relationships), or for forecasting.  We may select different approaches depending on our interest.  There are two main approaches we will consider here:
#
# 1. Regression on time-series data. This is about predicting a time series based on exogenous variables.
# 2. ARIMA modeling.  This is about predicting a time series as a function of its past values.
#
# We can also combine the two: ARIMA models with exogenous regressors.
#
# The focus today is on the modeling.  Pandas provides some nice data wrangling methods for working with time series data which are documented here:
#
# http://pandas.pydata.org/pandas-docs/stable/timeseries.html

# %% [markdown]
# ### Regression on time-series data

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# This data has
air = pd.read_csv('data/ausair.csv', parse_dates=['YEAR'], index_col='YEAR')
air
# Out:
#                AUSAIR  GUINEARICE
# YEAR
# 1970-01-01   7.318700    0.311405
# 1971-01-01   7.326600    0.325180
# 1972-01-01   7.795600    0.339565
# 1973-01-01   9.384600    0.354580
# 1974-01-01  10.664700    0.370265
# 1975-01-01  11.055100    0.386640
# 1976-01-01  10.864300    0.403740
# 1977-01-01  11.306500    0.421600
# 1978-01-01  12.122300    0.440250
# 1979-01-01  13.022500    0.459720
# 1980-01-01  13.648800    0.480055
# 1981-01-01  13.219500    0.501290
# 1982-01-01  13.187900    0.523460
# 1983-01-01  12.601500    0.546610
# 1984-01-01  13.236800    0.570790
# 1985-01-01  14.412100    0.596035
# 1986-01-01  15.497300    0.622395
# 1987-01-01  16.880200    0.649925
# 1988-01-01  18.816300    0.678670
# 1989-01-01  15.114300    0.708690
# 1990-01-01  17.553400    0.740035
# 1991-01-01  21.860100    0.772765
# 1992-01-01  23.886600    0.806945
# 1993-01-01  26.929300    0.842635
# 1994-01-01  26.888500    0.879905
# 1995-01-01  28.831400    0.918825
# 1996-01-01  30.075100    0.959460
# 1997-01-01  30.953500    1.001900
# 1998-01-01  30.185700    1.046220
# 1999-01-01  31.579700    1.092490
# 2000-01-01  32.577569    1.140810
# 2001-01-01  33.477398    1.033520
# 2002-01-01  39.021581    1.088670
# 2003-01-01  41.386432    1.146760
# 2004-01-01  41.596552    1.207960
# 2005-01-01  44.657324    1.272420
# 2006-01-01  46.951775    1.340310
# 2007-01-01  48.728837    1.401590
# 2008-01-01  51.488427    1.534090
# 2009-01-01  50.026967    1.499000

# %%
# Both time series are growing over the period of interest...

air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0CC3E9F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0CC8D6F0>], dtype=object)

# %%
# when we plot them against each other, they look to be highly correlated...

sns.jointplot(x="GUINEARICE", y="AUSAIR", data=air)

# %%
# so let's estimate a regression model

mod = smf.ols(formula='AUSAIR ~ GUINEARICE', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 AUSAIR   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     1272.
# Date:                Mon, 10 Apr 2017   Prob (F-statistic):           7.94e-31
# Time:                        17:10:54   Log-Likelihood:                -89.643
# No. Observations:                  40   AIC:                             183.3
# Df Residuals:                      38   BIC:                             186.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.7297      0.903     -6.348      0.000      -7.557      -3.902
# GUINEARICE    37.4101      1.049     35.672      0.000      35.287      39.533
# ==============================================================================
# Omnibus:                        1.905   Durbin-Watson:                   0.491
# Prob(Omnibus):                  0.386   Jarque-Bera (JB):                1.655
# Skew:                          -0.485   Prob(JB):                        0.437
# Kurtosis:                       2.774   Cond. No.                         4.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Woohoo!  We got an r-squared of 0.97.  This is a great model!  Right?

# %% [markdown]
# Sorry to disappoint, but this is an example of **spurious regression**.  Spurious regression can happen when working with time series that are non-stationary.
#
# Stationary: Model does not depwends on the time series in which it's observed.
#
# I would add that the model lacks a theoretical basis as well.  It clearly falls in the category of "If you can't explain it, you can't use it!"  However, spurious regression can occur even when there is a theoretical basis for the model.
#
# A stationary time series is one whose properties do not depend on the time at which the series is observed.  To avoid spurious regression, we want the dependent variable and all regressors to be stationary.

# %% [markdown]
# One way to tell if data are stationary is to plot them, and look for either a trend or a cycle

# %%
# check for trend or cycle

air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0D475C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0D56F7D0>], dtype=object)

# %% [markdown]
# We can also look at plots of the auto-correlation function (ACF).  auto-correlation is the correlation of the time-series past values.  There are some statistical tests for this as well, but often a graphical analysis is good enough.

# %%
# ACF plots

fig = sm.graphics.tsa.plot_acf(air['AUSAIR'], lags=30)
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE'], lags=30)

# %% [markdown]
# What do we do if the data are not stationary?  There are a few strategies, but differencing usually works.  All this means is subtracting each value from the previous value.  That way, you are modeling the change, rather than the total value.

# %%
# shift moves things by the specified number of rows

air['AUSAIR_DIFF'] = air['AUSAIR'] - air['AUSAIR'].shift(1)  
air['GUINEARICE_DIFF'] = air['GUINEARICE'] - air['GUINEARICE'].shift(1)  
air.head()
# Out:
#              AUSAIR  GUINEARICE  AUSAIR_DIFF  GUINEARICE_DIFF
# YEAR
# 1970-01-01   7.3187    0.311405          NaN              NaN
# 1971-01-01   7.3266    0.325180       0.0079         0.013775
# 1972-01-01   7.7956    0.339565       0.4690         0.014385
# 1973-01-01   9.3846    0.354580       1.5890         0.015015
# 1974-01-01  10.6647    0.370265       1.2801         0.015685

# %%
# now does it look stationary? 

air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0D636A10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0D679FF0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0D6AA2B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0D7D12B0>], dtype=object)

# %%
# ACF plots
# the first row is missing, so skip that one..

fig = sm.graphics.tsa.plot_acf(air['AUSAIR_DIFF'][1:], lags=30)
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE_DIFF'][1:], lags=30)

# %%
# if we have to, we can also calculate a second difference
# don't go beyond 2

air['AUSAIR_2DIFF'] = air['AUSAIR_DIFF'] - air['AUSAIR_DIFF'].shift(1)  
air['GUINEARICE_2DIFF'] = air['GUINEARICE_DIFF'] - air['GUINEARICE_DIFF'].shift(1)  
air.head()
# Out:
#              AUSAIR  GUINEARICE  AUSAIR_DIFF  GUINEARICE_DIFF  AUSAIR_2DIFF  \
# YEAR
# 1970-01-01   7.3187    0.311405          NaN              NaN           NaN
# 1971-01-01   7.3266    0.325180       0.0079         0.013775           NaN
# 1972-01-01   7.7956    0.339565       0.4690         0.014385        0.4611
# 1973-01-01   9.3846    0.354580       1.5890         0.015015        1.1200
# 1974-01-01  10.6647    0.370265       1.2801         0.015685       -0.3089
#
#             GUINEARICE_2DIFF
# YEAR
# 1970-01-01               NaN
# 1971-01-01               NaN
# 1972-01-01           0.00061
# 1973-01-01           0.00063
# 1974-01-01           0.00067

# %%
air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0DAD2BB0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0DBA1830>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0D7000B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0D636610>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0D71C870>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0DAB2730>], dtype=object)

# %%
# ACF plots
# the first two rows are missing, so skip those..
#This is a difference of the difference

fig = sm.graphics.tsa.plot_acf(air['AUSAIR_2DIFF'][2:], lags=30)
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE_2DIFF'][2:], lags=30)

# %%
# now what if we estimate the same model on the differenced data

mod = smf.ols(formula='AUSAIR_DIFF ~ GUINEARICE_DIFF', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            AUSAIR_DIFF   R-squared:                       0.125
# Model:                            OLS   Adj. R-squared:                  0.102
# Method:                 Least Squares   F-statistic:                     5.295
# Date:                Mon, 10 Apr 2017   Prob (F-statistic):             0.0271
# Time:                        17:11:38   Log-Likelihood:                -70.079
# No. Observations:                  39   AIC:                             144.2
# Df Residuals:                      37   BIC:                             147.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.5881      0.326      1.806      0.079      -0.072       1.248
# GUINEARICE_DIFF    16.6487      7.235      2.301      0.027       1.988      31.309
# ==============================================================================
# Omnibus:                        6.783   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):               10.436
# Skew:                          -0.123   Prob(JB):                      0.00542
# Kurtosis:                       5.522   Cond. No.                         30.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# now what if we estimate the same model on the second differenced data

mod = smf.ols(formula='AUSAIR_2DIFF ~ GUINEARICE_2DIFF', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           AUSAIR_2DIFF   R-squared:                       0.164
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     7.088
# Date:                Mon, 10 Apr 2017   Prob (F-statistic):             0.0115
# Time:                        17:11:39   Log-Likelihood:                -79.187
# No. Observations:                  38   AIC:                             162.4
# Df Residuals:                      36   BIC:                             165.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0150      0.324     -0.046      0.963      -0.673       0.642
# GUINEARICE_2DIFF    18.3687      6.900      2.662      0.012       4.376      32.362
# ==============================================================================
# Omnibus:                        6.128   Durbin-Watson:                   2.672
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                8.413
# Skew:                           0.116   Prob(JB):                       0.0149
# Kurtosis:                       5.293   Cond. No.                         21.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Homework
#
# The data folder contains a time-series data set of ridership on the BART rail system from 2001 through 2015.  Estimate a regression model of the ridership (RIDERS) as a function of variables included in the data set.  Build as complete of a model as you can, but be sure you can explain it!

# %%
BART = pd.read_csv('data/BARTEstimationFile.csv')
BART
# Out:
#           RIDERS      MONTH  STATIONS  CASH_FARE_2010USD_BART  \
# 0    321180.5238   1/1/2001        39                3.262745
# 1    334885.1053   2/1/2001        39                3.249754
# 2    340021.5455   3/1/2001        39                3.242376
# 3    333794.4286   4/1/2001        39                3.229546
# 4    333847.4545   5/1/2001        39                3.215007
# 5    329447.8095   6/1/2001        39                3.209588
# 6    324565.6000   7/1/2001        39                3.218629
# 7    321757.9130   8/1/2001        39                3.218629
# 8    321320.8421   9/1/2001        39                3.204188
# 9    315571.1818  10/1/2001        39                3.215007
# 10   317824.9474  11/1/2001        39                3.220444
# 11   292390.7222  12/1/2001        39                3.233202
# 12   300937.5714   1/1/2002        39                3.225899
# 12             2.462518            2.462518                 0.000000
# 13             2.452823            2.452823                 0.000000
# 14             2.439105            2.439105                 0.000000
# 15             2.425539            2.425539                 0.000000
# 16             2.425539            2.425539                 0.000000
# 17             2.424191            2.424191                 0.000000
# 18             2.421499            2.421499                 0.000000
# 19             2.413459            2.413459                 0.000000
# 20             2.409459            2.409459                 0.000000
# 21             2.405472            2.405472                 0.000000
# 22             2.405472            2.405472                 0.000000
# 23             2.410790            2.410790                 0.000000
# 24             2.400176            2.400176                 0.000000
# 25             2.381824            2.381824                 0.000000
# 26             2.367600            2.367600                 0.000000
# 27             2.372753            2.372753                 0.000000
# 28             2.376632            2.376632                 0.000000
# 29             2.374045            2.374045                 0.000000
# ..                  ...                 ...                      ...
# 147            5.626501            3.751001                 2.344376
# 148            5.616502            3.744334                 2.340209
# 149            5.603056            3.735371                 2.334607
# 150            5.600849            3.733900                 2.333687
# 151            5.594120            3.729413                 2.330883
# 152            5.587622            3.725081                 2.328176
# 153            5.602048            3.734699                 2.334187
# 154            5.613514            3.742342                 2.338964
# 155            5.613995            3.742664                 2.339165
# 156            5.593187            3.728792                 2.330495
# 157            5.572580            3.715054                 2.321909
# 158            5.536922            3.691282                 2.307051
# 159            5.518728            3.679152                 2.299470
# 160            5.499521            3.666347                 2.291467
# 161            5.489299            3.659533                 2.287208
# 162            5.491442            3.660961                 2.288101
# 163            5.500631            3.667087                 2.291929
# 164            5.496494            3.664329                 2.290206
# 165            5.510338            3.673558                 2.295974
# 166            5.540252            3.693501                 2.308438
# 167            5.571845            3.714563                 2.321602
# 168            5.598189            3.732126                 2.332579
# 169            5.573981            3.715987                 2.322492
# 170            5.541003            3.694002                 2.308751
# 171                 NaN                 NaN                      NaN
# 172                 NaN                 NaN                      NaN
# 173                 NaN                 NaN                      NaN
# 174                 NaN                 NaN                      NaN
# 175                 NaN                 NaN                      NaN
# 176                 NaN                 NaN                      NaN
#
#      CASUAL_CARPOOL  BART_STRIKE
# 0                 1            0
# 1                 1            0
# 2                 1            0
# 3                 1            0
# 4                 1            0
# 5                 1            0
# 6                 1            0
# 7                 1            0
# 8                 1            0
# 9                 1            0
# 10                1            0
# 11                1            0
# 12                1            0
# 13                1            0
# 14                1            0
# 15                1            0
# 16                1            0
# 17                1            0
# 18                1            0
# 19                1            0
# 20                1            0
# 21                1            0
# 22                1            0
# 23                1            0
# 24                1            0
# 25                1            0
# 26                1            0
# 27                1            0
# 28                1            0
# 29                1            0
# ..              ...          ...
# 147               0            0
# 148               0            0
# 149               0            0
# 150               0            1
# 151               0            0
# 152               0            0
# 153               0            1
# 154               0            0
# 155               0            0
# 156               0            0
# 157               0            0
# 158               0            0
# 159               0            0
# 160               0            0
# 161               0            0
# 162               0            0
# 163               0            0
# 164               0            0
# 165               0            0
# 166               0            0
# 167               0            0
# 168               0            0
# 169               0            0
# 170               0            0
# 171               1            0
# 172               1            0
# 173               1            0
# 174               1            0
# 175               1            0
# 176               1            0
#
# [177 rows x 23 columns]

# %%
BART.plot(x='MONTH',y='RIDERS')

# %%
BART.plot(x='MONTH',y='RIDERS_DIFF')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'RIDERS_DIFF'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-3ccba4ed171c> in <module>()
# ----> 1 BART.plot(x='MONTH',y='RIDERS_DIFF')
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tools\plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tools\plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tools\plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2454                     y = data.columns[y]
#    2455                 label = kwds['label'] if 'label' in kwds else y
# -> 2456                 series = data[y].copy()  # Don't modify
#    2457                 series.name = label
#    2458
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'RIDERS_DIFF'

# %%
BART.plot(x='MONTH',y='RIDERS_DIFF_DIFF')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'RIDERS_DIFF_DIFF'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-60d438422c18> in <module>()
# ----> 1 BART.plot(x='MONTH',y='RIDERS_DIFF_DIFF')
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tools\plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tools\plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tools\plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2454                     y = data.columns[y]
#    2455                 label = kwds['label'] if 'label' in kwds else y
# -> 2456                 series = data[y].copy()  # Don't modify
#    2457                 series.name = label
#    2458
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'RIDERS_DIFF_DIFF'

# %%
BART.plot(x='MONTH',y='AVG_FARE_2010USD_BART')

# %%
BART.plot(x='MONTH',y='FUEL_PRICE_2010USD')

# %%
BART.plot(x='MONTH',y='TOLL_BB_PK_2010USD')

# %%
BART.plot(x='MONTH',y='TOLL_BB_OP_2010USD')

# %%
def difference1(bart):
    bart['RIDERS_DIFF'] = bart['RIDERS'] - bart['RIDERS'].shift(12)  
    bart['AVG_FARE_2010USD_BART_DIFF'] = bart['AVG_FARE_2010USD_BART'] - bart['AVG_FARE_2010USD_BART'].shift(12)  
    bart['FUEL_PRICE_2010USD_DIFF'] = bart['FUEL_PRICE_2010USD'] - bart['FUEL_PRICE_2010USD'].shift(12)
    bart['TOLL_BB_PK_2010USD_DIFF'] = bart['TOLL_BB_PK_2010USD'] - bart['TOLL_BB_PK_2010USD'].shift(12)
    bart['TOLL_BB_OP_2010USD_DIFF'] = bart['TOLL_BB_OP_2010USD'] - bart['TOLL_BB_OP_2010USD'].shift(12)
    return bart.head()

# %%
def difference2(bart):
    bart['RIDERS_DIFF_DIFF'] = bart['RIDERS_DIFF'] - bart['RIDERS_DIFF'].shift(12)  
    #bart['AVG_FARE_2010USD_BART_DIFF'] = bart['AVG_FARE_2010USD_BART'] - bart['AVG_FARE_2010USD_BART'].shift(12)  
    #bart['FUEL_PRICE_2010USD_DIFF'] = bart['FUEL_PRICE_2010USD'] - bart['FUEL_PRICE_2010USD'].shift(12)
    #bart['TOLL_BB_PK_2010USD_DIFF'] = bart['TOLL_BB_PK_2010USD'] - bart['TOLL_BB_PK_2010USD'].shift(12)
    #bart['TOLL_BB_OP_2010USD_DIFF'] = bart['TOLL_BB_OP_2010USD'] - bart['TOLL_BB_OP_2010USD'].shift(12)
    return bart.head()

# %%
difference1(BART)
# Out:
#         RIDERS     MONTH  STATIONS  CASH_FARE_2010USD_BART  \
# 0  321180.5238  1/1/2001        39                3.262745
# 1  334885.1053  2/1/2001        39                3.249754
# 2  340021.5455  3/1/2001        39                3.242376
# 3  333794.4286  4/1/2001        39                3.229546
# 4  333847.4545  5/1/2001        39                3.215007
#
#    AVG_FARE_2010USD_BART           HH      HH_0VEH          POP      WORKERS  \
# 0               2.555435  1452556.571  187359.1429  3870692.571  1924489.571
# 1               2.545259  1452696.413  187278.4921  3870052.746  1923471.413
# 2               2.539481  1452836.254  187197.8413  3869412.921  1922453.254
# 3               2.529432  1452976.095  187117.1905  3868773.095  1921435.095
# 4               2.518045  1453115.937  187036.5397  3868133.270  1920416.937
#
#    MEDIAN_HHINC_2010USD           ...             TOLL_BB_PK_2010USD  \
# 0           85841.07733           ...                       2.490645
# 1           85401.59874           ...                       2.480728
# 2           85110.28356           ...                       2.475096
# 3           84676.45762           ...                       2.465302
# 4           84198.65633           ...                       2.454204
#
#    TOLL_BB_OP_2010USD  TOLL_BB_CARPOOL_2010USD  CASUAL_CARPOOL  BART_STRIKE  \
# 0            2.490645                      0.0               1            0
# 1            2.480728                      0.0               1            0
# 2            2.475096                      0.0               1            0
# 3            2.465302                      0.0               1            0
# 4            2.454204                      0.0               1            0
#
#    RIDERS_DIFF  AVG_FARE_2010USD_BART_DIFF  FUEL_PRICE_2010USD_DIFF  \
# 0          NaN                         NaN                      NaN
# 1          NaN                         NaN                      NaN
# 2          NaN                         NaN                      NaN
# 3          NaN                         NaN                      NaN
# 4          NaN                         NaN                      NaN
#
#    TOLL_BB_PK_2010USD_DIFF  TOLL_BB_OP_2010USD_DIFF
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
# [5 rows x 28 columns]

# %%
difference2(BART)
# Out:
#         RIDERS     MONTH  STATIONS  CASH_FARE_2010USD_BART  \
# 0  321180.5238  1/1/2001        39                3.262745
# 1  334885.1053  2/1/2001        39                3.249754
# 2  340021.5455  3/1/2001        39                3.242376
# 3  333794.4286  4/1/2001        39                3.229546
# 4  333847.4545  5/1/2001        39                3.215007
#
#    AVG_FARE_2010USD_BART           HH      HH_0VEH          POP      WORKERS  \
# 0               2.555435  1452556.571  187359.1429  3870692.571  1924489.571
# 1               2.545259  1452696.413  187278.4921  3870052.746  1923471.413
# 2               2.539481  1452836.254  187197.8413  3869412.921  1922453.254
# 3               2.529432  1452976.095  187117.1905  3868773.095  1921435.095
# 4               2.518045  1453115.937  187036.5397  3868133.270  1920416.937
#
#    MEDIAN_HHINC_2010USD        ...         TOLL_BB_OP_2010USD  \
# 0           85841.07733        ...                   2.490645
# 1           85401.59874        ...                   2.480728
# 2           85110.28356        ...                   2.475096
# 3           84676.45762        ...                   2.465302
# 4           84198.65633        ...                   2.454204
#
#    TOLL_BB_CARPOOL_2010USD  CASUAL_CARPOOL  BART_STRIKE  RIDERS_DIFF  \
# 0                      0.0               1            0          NaN
# 1                      0.0               1            0          NaN
# 2                      0.0               1            0          NaN
# 3                      0.0               1            0          NaN
# 4                      0.0               1            0          NaN
#
#    AVG_FARE_2010USD_BART_DIFF  FUEL_PRICE_2010USD_DIFF  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
#
#    TOLL_BB_PK_2010USD_DIFF  TOLL_BB_OP_2010USD_DIFF  RIDERS_DIFF_DIFF
# 0                      NaN                      NaN               NaN
# 1                      NaN                      NaN               NaN
# 2                      NaN                      NaN               NaN
# 3                      NaN                      NaN               NaN
# 4                      NaN                      NaN               NaN
#
# [5 rows x 29 columns]

# %%
fig = sm.graphics.tsa.plot_acf(BART['RIDERS_DIFF'][12:], lags=30)
fig = sm.graphics.tsa.plot_acf(BART['RIDERS_DIFF_DIFF'][24:], lags=30)
fig = sm.graphics.tsa.plot_acf(BART['AVG_FARE_2010USD_BART'][12:], lags=30)
fig = sm.graphics.tsa.plot_acf(BART['FUEL_PRICE_2010USD'][12:], lags=30)
fig = sm.graphics.tsa.plot_acf(BART['TOLL_BB_PK_2010USD'][12:], lags=30)
fig = sm.graphics.tsa.plot_acf(BART['TOLL_BB_OP_2010USD'][12:], lags=30)

# %%
mod = smf.ols(formula='RIDERS_DIFF_DIFF ~ AVG_FARE_2010USD_BART + FUEL_PRICE_2010USD + TOLL_BB_PK_2010USD + TOLL_BB_OP_2010USD + CASUAL_CARPOOL + BART_STRIKE', data=BART)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       RIDERS_DIFF_DIFF   R-squared:                       0.352
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     12.65
# Date:                Mon, 10 Apr 2017   Prob (F-statistic):           2.26e-11
# Time:                        17:46:11   Log-Likelihood:                -1681.3
# No. Observations:                 147   AIC:                             3377.
# Df Residuals:                     140   BIC:                             3398.
# Df Model:                           6
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept             -1.809e+05   1.28e+05     -1.414      0.160   -4.34e+05    7.21e+04
# AVG_FARE_2010USD_BART -2.135e+04   1.94e+04     -1.099      0.274   -5.97e+04    1.71e+04
# FUEL_PRICE_2010USD     6111.6187   4479.445      1.364      0.175   -2744.485     1.5e+04
# TOLL_BB_PK_2010USD     1.603e+05    6.4e+04      2.505      0.013    3.38e+04    2.87e+05
# TOLL_BB_OP_2010USD     -1.78e+05   6.46e+04     -2.754      0.007   -3.06e+05   -5.02e+04
# CASUAL_CARPOOL         2.836e+05   1.22e+05      2.334      0.021    4.34e+04    5.24e+05
# BART_STRIKE           -1.001e+05   1.68e+04     -5.962      0.000   -1.33e+05   -6.69e+04
# ==============================================================================
# Omnibus:                      123.023   Durbin-Watson:                   1.318
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1886.999
# Skew:                           2.825   Prob(JB):                         0.00
# Kurtosis:                      19.618   Cond. No.                         749.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#According to my model, average vare is not significant. 
#Therefore, it will be dropped out of the model to reduce model redundancy

# %%
mod = smf.ols(formula='RIDERS_DIFF_DIFF ~ FUEL_PRICE_2010USD + TOLL_BB_PK_2010USD + TOLL_BB_OP_2010USD + CASUAL_CARPOOL + BART_STRIKE', data=BART)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       RIDERS_DIFF_DIFF   R-squared:                       0.346
# Model:                            OLS   Adj. R-squared:                  0.323
# Method:                 Least Squares   F-statistic:                     14.92
# Date:                Mon, 10 Apr 2017   Prob (F-statistic):           9.70e-12
# Time:                        17:47:19   Log-Likelihood:                -1681.9
# No. Observations:                 147   AIC:                             3376.
# Df Residuals:                     141   BIC:                             3394.
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept          -2.246e+05   1.22e+05     -1.845      0.067   -4.65e+05     1.6e+04
# FUEL_PRICE_2010USD  6880.8374   4427.671      1.554      0.122   -1872.365    1.56e+04
# TOLL_BB_PK_2010USD  1.554e+05   6.39e+04      2.433      0.016    2.92e+04    2.82e+05
# TOLL_BB_OP_2010USD -1.767e+05   6.47e+04     -2.733      0.007   -3.05e+05   -4.89e+04
# CASUAL_CARPOOL      2.788e+05   1.22e+05      2.294      0.023    3.85e+04    5.19e+05
# BART_STRIKE        -9.793e+04   1.67e+04     -5.869      0.000   -1.31e+05   -6.49e+04
# ==============================================================================
# Omnibus:                      120.219   Durbin-Watson:                   1.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1807.040
# Skew:                           2.737   Prob(JB):                         0.00
# Kurtosis:                      19.281   Cond. No.                         686.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Same for Fuel Price

# %%
mod = smf.ols(formula='RIDERS_DIFF_DIFF ~ TOLL_BB_PK_2010USD + TOLL_BB_OP_2010USD + CASUAL_CARPOOL + BART_STRIKE', data=BART)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       RIDERS_DIFF_DIFF   R-squared:                       0.335
# Model:                            OLS   Adj. R-squared:                  0.316
# Method:                 Least Squares   F-statistic:                     17.86
# Date:                Mon, 10 Apr 2017   Prob (F-statistic):           6.71e-12
# Time:                        17:47:47   Log-Likelihood:                -1683.2
# No. Observations:                 147   AIC:                             3376.
# Df Residuals:                     142   BIC:                             3391.
# Df Model:                           4
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept          -1.908e+05    1.2e+05     -1.585      0.115   -4.29e+05    4.71e+04
# TOLL_BB_PK_2010USD  1.441e+05   6.38e+04      2.259      0.025     1.8e+04     2.7e+05
# TOLL_BB_OP_2010USD -1.621e+05   6.43e+04     -2.521      0.013   -2.89e+05    -3.5e+04
# CASUAL_CARPOOL      2.537e+05   1.21e+05      2.096      0.038    1.44e+04    4.93e+05
# BART_STRIKE        -9.735e+04   1.68e+04     -5.807      0.000    -1.3e+05   -6.42e+04
# ==============================================================================
# Omnibus:                      115.498   Durbin-Watson:                   1.283
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1631.683
# Skew:                           2.605   Prob(JB):                         0.00
# Kurtosis:                      18.468   Cond. No.                         594.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Based on the latest regression model, we can see that all coefficients are significant.  However, there are some weird coefficients in the model.  For example, Peak Toll and Normal operating tool have the opposite effect on BART ridership.  This is strange because typically these should be correlated and that was what I was expecting.  The charts below show the plots for riders after transformation and each toll type:

# %%
sns.jointplot(x="TOLL_BB_PK_2010USD", y="RIDERS_DIFF_DIFF", data=BART)

# %%
sns.jointplot(x="TOLL_BB_OP_2010USD", y="RIDERS_DIFF_DIFF", data=BART)

# %% [markdown]
# As can be seen from the above plots, when by itself, peak tolls do not have an appreciable effect on BART ridership by itself.  It is only when the variables above are held constant when an appreciable effect can be garnered.  Given BART ridership shouldn't increase when tolls increase, this variable cannot be explained and should be thrown out.

# %%
mod = smf.ols(formula='RIDERS_DIFF_DIFF ~ TOLL_BB_OP_2010USD + CASUAL_CARPOOL + BART_STRIKE', data=BART)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       RIDERS_DIFF_DIFF   R-squared:                       0.311
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     21.50
# Date:                Mon, 10 Apr 2017   Prob (F-statistic):           1.50e-11
# Time:                        18:40:37   Log-Likelihood:                -1685.8
# No. Observations:                 147   AIC:                             3380.
# Df Residuals:                     143   BIC:                             3391.
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           7.926e+04   1.44e+04      5.515      0.000    5.09e+04    1.08e+05
# TOLL_BB_OP_2010USD -1.706e+04   3690.881     -4.623      0.000   -2.44e+04   -9766.257
# CASUAL_CARPOOL     -1.963e+04   4170.829     -4.707      0.000   -2.79e+04   -1.14e+04
# BART_STRIKE        -1.019e+05   1.69e+04     -6.035      0.000   -1.35e+05   -6.85e+04
# ==============================================================================
# Omnibus:                       86.445   Durbin-Watson:                   1.244
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              757.649
# Skew:                           1.896   Prob(JB):                    3.01e-165
# Kurtosis:                      13.456   Cond. No.                         33.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The final code does make sense.  It states that for holding all the other variables constant, the variable in question is going to change with significance.  Also, the only continuous variable is tolls for operation and the categoricals are carpool a
