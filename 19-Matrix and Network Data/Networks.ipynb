# %% [markdown]
# # Networks
#
# Networks are another important data structure in transportaiton.  Think roadway networks in particular, but many things can be represented as a network.  We'll go over a few basics in class.
#
# MPOs or DOTs with a travel model will maintain a network representation of the street network for use in the model.  This will have the attributes the model needs: free flow speed, capacity, length, directionality, turn restrictions, facility type, etc.  Usually, the best way to get a copy is to call up your friendly local transportation modler and ask.  Even in this tech-crazy world, it is amazing how far asking politely will get you...
#
# ...however, that's not what we're going to do here.  Instead, we are going to work with network data from OpenStreetMap:
#
# http://www.openstreetmap.org/
#
# To make it easier, we will work with a package called OSMnx, by Geoff Boeing. You can read a paper on the toolkit here:
#
# https://www.researchgate.net/publication/309738462_OSMNX_New_Methods_for_Acquiring_Constructing_Analyzing_and_Visualizing_Complex_Street_Networks
#
# And a blog post here:
#
# http://geoffboeing.com/2016/11/osmnx-python-street-networks/

# %% [markdown]
# ### Homework
#
# Your homework is to:
#
# 1. Read the network paper linked above.
#
# 2. Use the blog post to figure out how to install and use the package.
#
# 3. Get the street network for Lexington.
#
# 4. Print the basic_stats for the network.
#
# 5. Calculate and show the shortest path from your home (or another point of interest) to UK campus.  Is this the route you would take?  What is the same or different?
#
# 6. Repeat step 5 for three other trips that you make regularly.

# %%
import osmnx as ox
import networkx as nx
city = ox.gdf_from_place('Fayette County, KY')
ox.plot_shape(ox.project_gdf(city))
# Out:
# (<matplotlib.figure.Figure at 0x12548530>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1257ba30>)

# %%
G = ox.graph_from_place('Fayette County, Kentucky', network_type='drive')
ox.plot_graph(G)
# Out:
# (<matplotlib.figure.Figure at 0x158502b0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x15850910>)

# %%
G = ox.graph_from_place('Fayette County, Kentucky', network_type='drive')
basic_stats = ox.basic_stats(G)
print(basic_stats)
# Out:
# {'street_density_km': None, 'edge_length_avg': 176.80854163159768, 'n': 10496, 'circuity_avg': 1.0812454611962887, 'street_length_total': 2563449.2973720781, 'streets_per_node_proportion': {0: 0.0, 1: 0.2533346036585366, 2: 0.003429878048780488, 3: 0.5625952743902439, 4: 0.17682926829268292, 5: 0.003715701219512195, 6: 9.527439024390244e-05}, 'street_segments_count': 14139, 'street_length_avg': 181.30343711521877, 'edge_density_km': None, 'k_avg': 4.893483231707317, 'm': 25681, 'streets_per_node_counts': {0: 0, 1: 2659, 2: 36, 3: 5905, 4: 1856, 5: 39, 6: 1}, 'intersection_density_km': None, 'streets_per_node_avg': 2.6744474085365852, 'edge_length_total': 4540620.1576410597, 'self_loop_proportion': 0.010786184338616098, 'node_density_km': None, 'count_intersections': 7837}

# %%
G = ox.graph_from_address('3200 Todds Road, Fayette County, Kentucky', distance = 800, network_type='drive')
route = nx.shortest_path(G, origin, destination)
ox.plot_graph_route(G, route)
# Out:
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\socket.py:646: ResourceWarning: unclosed <socket.socket fd=1716, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('10.163.143.33', 56430), raddr=('193.63.75.109', 443)>
#   self._sock = None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\classes\digraph.py in successors_iter(self, n)
#     748         try:
# --> 749             return iter(self.succ[n])
#     750         except KeyError:
#
# KeyError: <networkx.classes.multidigraph.MultiDiGraph object at 0x12548370>
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-7-0119b039c468> in <module>()
#       1 G = ox.graph_from_address('3200 Todds Road, Fayette County, Kentucky', distance = 800, network_type='drive')
# ----> 2 route = nx.shortest_path(G, origin, destination)
#       3 ox.plot_graph_route(G, route)
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\algorithms\shortest_paths\generic.py in shortest_path(G, source, target, weight)
#     134             ## Find shortest source-target path.
#     135             if weight is None:
# --> 136                 paths=nx.bidirectional_shortest_path(G,source,target)
#     137             else:
#     138                 paths=nx.dijkstra_path(G,source,target,weight)
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py in bidirectional_shortest_path(G, source, target)
#     134     """
#     135     # call helper to do the real work
# --> 136     results=_bidirectional_pred_succ(G,source,target)
#     137     pred,succ,w=results
#     138
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py in _bidirectional_pred_succ(G, source, target)
#     184             forward_fringe=[]
#     185             for v in this_level:
# --> 186                 for w in Gsucc(v):
#     187                     if w not in pred:
#     188                         forward_fringe.append(w)
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\classes\digraph.py in successors_iter(self, n)
#     749             return iter(self.succ[n])
#     750         except KeyError:
# --> 751             raise NetworkXError("The node %s is not in the digraph."%(n,))
#     752
#     753     def predecessors_iter(self,n):
#
# NetworkXError: The node unnamed is not in the digraph.

# %%
#What I want to do with the code
#Need Lat Longs for Origins and Destiations
G = ox.graph_from_address('Fayette County, Kentucky', network_type='drive')
origin = (38.006763 , -84.)
destination = 
orig_node = ox.get_nearest_node(G, origin)
dest_node = ox.get_earest_node(G, destination)
route = nx.shortest_path(G, orig_node, dest_node)
ox.plot_graph_route(G, route)
# Out:
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\socket.py:646: ResourceWarning: unclosed <socket.socket fd=1608, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('10.163.143.33', 53078), raddr=('193.63.75.109', 443)>
#   self._sock = None
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\socket.py:646: ResourceWarning: unclosed <socket.socket fd=1696, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('10.163.143.33', 53086), raddr=('193.63.75.109', 443)>
#   self._sock = None
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\socket.py:646: ResourceWarning: unclosed <socket.socket fd=1708, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('10.163.143.33', 53090), raddr=('193.63.75.109', 443)>
#   self._sock = None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-ac9bd4356c26> in <module>()
#       3 origin = ox.graph_from_address('3200 Todds Road, Fayette County, KY', network_type='drive')
#       4 destination = ox.graph_from_address('University of Kentucky', network_type='drive')
# ----> 5 orig_node = ox.get_nearest_node(G, origin)
#       6 dest_node = ox.get_earest_node(G, destination)
#       7 route = nx.shortest_path(G, orig_node, dest_node)
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\osmnx\utils.py in get_nearest_node(G, point, return_dist)
#     296
#     297     # add columns to the dataframe representing the (constant) coordinates of the reference point
# --> 298     df['reference_y'] = point[0]
#     299     df['reference_x'] = point[1]
#     300
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\classes\graph.py in __getitem__(self, n)
#     405         {1: {}}
#     406         """
# --> 407         return self.adj[n]
#     408
#     409     def add_node(self, n, attr_dict=None, **attr):
#
# KeyError: 0

# %%
#Stock Code from blog
G = ox.graph_from_address('N. Sicily Pl., Chandler, Arizona', distance=800, network_type='drive')
route = nx.shortest_path(G, origin, destination)
ox.plot_graph_route(G, route)
# Out:
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\socket.py:646: ResourceWarning: unclosed <socket.socket fd=1664, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('10.163.143.33', 63353), raddr=('193.63.75.109', 443)>
#   self._sock = None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\classes\digraph.py in successors_iter(self, n)
#     748         try:
# --> 749             return iter(self.succ[n])
#     750         except KeyError:
#
# KeyError: <networkx.classes.multidigraph.MultiDiGraph object at 0x12548370>
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-8-f488109e0c5f> in <module>()
#       1 #Stock Code from blog
#       2 G = ox.graph_from_address('N. Sicily Pl., Chandler, Arizona', distance=800, network_type='drive')
# ----> 3 route = nx.shortest_path(G, origin, destination)
#       4 ox.plot_graph_route(G, route)
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\algorithms\shortest_paths\generic.py in shortest_path(G, source, target, weight)
#     134             ## Find shortest source-target path.
#     135             if weight is None:
# --> 136                 paths=nx.bidirectional_shortest_path(G,source,target)
#     137             else:
#     138                 paths=nx.dijkstra_path(G,source,target,weight)
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py in bidirectional_shortest_path(G, source, target)
#     134     """
#     135     # call helper to do the real work
# --> 136     results=_bidirectional_pred_succ(G,source,target)
#     137     pred,succ,w=results
#     138
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py in _bidirectional_pred_succ(G, source, target)
#     184             forward_fringe=[]
#     185             for v in this_level:
# --> 186                 for w in Gsucc(v):
#     187                     if w not in pred:
#     188                         forward_fringe.append(w)
#
# C:\Users\jdbr223\AppData\Local\Continuum\Anaconda3\lib\site-packages\networkx\classes\digraph.py in successors_iter(self, n)
#     749             return iter(self.succ[n])
#     750         except KeyError:
# --> 751             raise NetworkXError("The node %s is not in the digraph."%(n,))
#     752
#     753     def predecessors_iter(self,n):
#
# NetworkXError: The node unnamed is not in the digraph.
