# %% [markdown]
# # Correlation, Causality and multiCollinearity
#
# For a good explanation, see:
#
# https://www.otexts.org/fpp/5/7
#
# Let's stop and check that out.

# %% [markdown]
# ### Back to our BART data

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# This data has
bart = pd.read_csv('data/BARTEstimationFile.csv', parse_dates=['MONTH'], index_col='MONTH')
bart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 177 entries, 2001-01-01 to 2015-09-01
# Data columns (total 22 columns):
# RIDERS                     177 non-null float64
# STATIONS                   177 non-null int64
# CASH_FARE_2010USD_BART     175 non-null float64
# AVG_FARE_2010USD_BART      175 non-null float64
# HH                         168 non-null float64
# HH_0VEH                    168 non-null float64
# POP                        168 non-null float64
# WORKERS                    168 non-null float64
# MEDIAN_HHINC_2010USD       168 non-null float64
# SERVMILES_E_BART           177 non-null float64
# TOTEMP                     171 non-null float64
# RETAIL_EMP                 171 non-null float64
# EDHEALTH_EMP               171 non-null float64
# LEISURE_EMP                171 non-null float64
# OTHER_EMP                  171 non-null float64
# FUEL_PRICE_2010USD         171 non-null float64
# FUEL_COST_2010USD          171 non-null float64
# TOLL_BB_PK_2010USD         171 non-null float64
# TOLL_BB_OP_2010USD         171 non-null float64
# TOLL_BB_CARPOOL_2010USD    171 non-null float64
# CASUAL_CARPOOL             177 non-null int64
# BART_STRIKE                177 non-null int64
# dtypes: float64(19), int64(3)
# memory usage: 31.8 KB

# %%
# drop missing values
bart = bart.dropna()

# calculate second difference
diff = bart - bart.shift(12)
diff2 = diff - diff.shift(1)
diff2['RIDERS'].plot()

# %%
# start from the variables we think are important

mod = smf.ols(formula='RIDERS ~ \
              SERVMILES_E_BART \
              + TOTEMP \
              + WORKERS \
              + CASH_FARE_2010USD_BART \
              + FUEL_COST_2010USD \
              + BART_STRIKE \
              - 1', 
              data=diff2[13:])
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.831
# Method:                 Least Squares   F-statistic:                     127.8
# Date:                Wed, 12 Apr 2017   Prob (F-statistic):           3.59e-56
# Time:                        08:55:05   Log-Likelihood:                -1591.1
# No. Observations:                 155   AIC:                             3194.
# Df Residuals:                     149   BIC:                             3212.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# SERVMILES_E_BART           0.4393      1.428      0.308      0.759      -2.382       3.261
# TOTEMP                     0.1187      0.057      2.073      0.040       0.006       0.232
# WORKERS                    0.2846      0.142      2.006      0.047       0.004       0.565
# CASH_FARE_2010USD_BART -1.596e+04   1.12e+04     -1.421      0.157   -3.81e+04    6228.685
# FUEL_COST_2010USD       4.839e+04   5.23e+04      0.925      0.356    -5.5e+04    1.52e+05
# BART_STRIKE            -6.902e+04   2516.131    -27.429      0.000    -7.4e+04    -6.4e+04
# ==============================================================================
# Omnibus:                        1.986   Durbin-Watson:                   2.636
# Prob(Omnibus):                  0.370   Jarque-Bera (JB):                1.533
# Skew:                           0.019   Prob(JB):                        0.465
# Kurtosis:                       2.514   Cond. No.                     9.80e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# start from the variables we think are important

mod = smf.ols(formula='RIDERS ~ \
              SERVMILES_E_BART \
              + TOTEMP \
              + WORKERS \
              + CASH_FARE_2010USD_BART \
              + BART_STRIKE \
              - 1', 
              data=diff2[13:])
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.831
# Method:                 Least Squares   F-statistic:                     153.3
# Date:                Tue, 11 Apr 2017   Prob (F-statistic):           4.21e-57
# Time:                        13:49:00   Log-Likelihood:                -1591.5
# No. Observations:                 155   AIC:                             3193.
# Df Residuals:                     150   BIC:                             3208.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# SERVMILES_E_BART           0.4122      1.427      0.289      0.773      -2.407       3.231
# TOTEMP                     0.1230      0.057      2.156      0.033       0.010       0.236
# WORKERS                    0.3033      0.140      2.162      0.032       0.026       0.581
# CASH_FARE_2010USD_BART -1.843e+04   1.09e+04     -1.691      0.093      -4e+04    3100.915
# BART_STRIKE              -6.9e+04   2514.848    -27.436      0.000    -7.4e+04    -6.4e+04
# ==============================================================================
# Omnibus:                        1.629   Durbin-Watson:                   2.627
# Prob(Omnibus):                  0.443   Jarque-Bera (JB):                1.393
# Skew:                           0.068   Prob(JB):                        0.498
# Kurtosis:                       2.556   Cond. No.                     2.04e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.04e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# start from the variables we think are important

mod = smf.ols(formula='RIDERS ~ \
              SERVMILES_E_BART \
              + TOTEMP \
              + WORKERS \
              + FUEL_COST_2010USD \
              + BART_STRIKE \
              - 1', 
              data=diff2[13:])
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                     151.9
# Date:                Tue, 11 Apr 2017   Prob (F-statistic):           7.50e-57
# Time:                        13:49:23   Log-Likelihood:                -1592.1
# No. Observations:                 155   AIC:                             3194.
# Df Residuals:                     150   BIC:                             3209.
# Df Model:                           5
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# SERVMILES_E_BART      0.4627      1.433      0.323      0.747      -2.368       3.293
# TOTEMP                0.1225      0.057      2.136      0.034       0.009       0.236
# WORKERS               0.2827      0.142      1.986      0.049       0.001       0.564
# FUEL_COST_2010USD  6.612e+04    5.1e+04      1.297      0.197   -3.46e+04    1.67e+05
# BART_STRIKE       -6.898e+04   2524.521    -27.323      0.000    -7.4e+04    -6.4e+04
# ==============================================================================
# Omnibus:                        3.017   Durbin-Watson:                   2.608
# Prob(Omnibus):                  0.221   Jarque-Bera (JB):                2.007
# Skew:                           0.025   Prob(JB):                        0.367
# Kurtosis:                       2.445   Cond. No.                     9.50e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.5e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# It seems like we might have multicollinearity issues.  There are some statistical tests for this, or we can examine the covariance matrix.  For now, let's see if we can figure out what's going on a bit more intuitively.

# %%
# a simple thing we can do is look at the data

fields = ['RIDERS', 'SERVMILES_E_BART', 'TOTEMP', 'WORKERS', 'CASH_FARE_2010USD_BART', 'FUEL_COST_2010USD', 'BART_STRIKE']

sns.pairplot(diff2[fields][13:])

#See cash fare vs fuel?

# %%
fields = ['RIDERS', 'SERVMILES_E_BART', 'TOTEMP', 'WORKERS', 'CASH_FARE_2010USD_BART', 'FUEL_COST_2010USD', 'BART_STRIKE']

bart[fields][13:].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0EEC19F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0EEFDB30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0EF1C270>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0EF342D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0EF5E9D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0EF86730>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0EFB0A30>], dtype=object)

# %%
# workers and totemp seem to move together.  What if we drop one or the other? 

mod = smf.ols(formula='RIDERS ~ \
              SERVMILES_E_BART \
              + TOTEMP \
              + CASH_FARE_2010USD_BART \
              + FUEL_COST_2010USD \
              + BART_STRIKE \
              - 1', 
              data=diff2[13:])
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.827
# Method:                 Least Squares   F-statistic:                     149.5
# Date:                Tue, 11 Apr 2017   Prob (F-statistic):           2.01e-56
# Time:                        13:42:47   Log-Likelihood:                -1593.1
# No. Observations:                 155   AIC:                             3196.
# Df Residuals:                     150   BIC:                             3211.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# SERVMILES_E_BART           0.7723      1.432      0.539      0.591      -2.058       3.603
# TOTEMP                     0.1512      0.055      2.726      0.007       0.042       0.261
# CASH_FARE_2010USD_BART -1.574e+04   1.13e+04     -1.388      0.167   -3.82e+04    6662.325
# FUEL_COST_2010USD       6.337e+04   5.23e+04      1.212      0.227   -3.99e+04    1.67e+05
# BART_STRIKE            -6.919e+04   2539.787    -27.244      0.000   -7.42e+04   -6.42e+04
# ==============================================================================
# Omnibus:                        2.980   Durbin-Watson:                   2.612
# Prob(Omnibus):                  0.225   Jarque-Bera (JB):                2.001
# Skew:                          -0.036   Prob(JB):                        0.368
# Kurtosis:                       2.448   Cond. No.                     9.62e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.62e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# workers and totemp seem to move together.  What if we drop one or the other? 

mod = smf.ols(formula='RIDERS ~ \
              SERVMILES_E_BART \
              + WORKERS \
              + CASH_FARE_2010USD_BART \
              + FUEL_COST_2010USD \
              + BART_STRIKE \
              - 1', 
              data=diff2[13:])
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.827
# Method:                 Least Squares   F-statistic:                     149.2
# Date:                Tue, 11 Apr 2017   Prob (F-statistic):           2.30e-56
# Time:                        13:43:06   Log-Likelihood:                -1593.3
# No. Observations:                 155   AIC:                             3197.
# Df Residuals:                     150   BIC:                             3212.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# SERVMILES_E_BART           0.0691      1.432      0.048      0.962      -2.761       2.899
# WORKERS                    0.3678      0.138      2.674      0.008       0.096       0.640
# CASH_FARE_2010USD_BART -1.707e+04   1.13e+04     -1.505      0.134   -3.95e+04    5336.780
# FUEL_COST_2010USD        5.72e+04   5.27e+04      1.085      0.280   -4.69e+04    1.61e+05
# BART_STRIKE            -6.861e+04   2535.915    -27.055      0.000   -7.36e+04   -6.36e+04
# ==============================================================================
# Omnibus:                        1.621   Durbin-Watson:                   2.640
# Prob(Omnibus):                  0.445   Jarque-Bera (JB):                1.367
# Skew:                           0.051   Prob(JB):                        0.505
# Kurtosis:                       2.551   Cond. No.                     3.91e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.91e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Notice how the coefficients change.  One thing we can try is to specify a different variable that gets at a similar effect, but might be less collinear.

# %%
# what if we substitute population for workers?

mod = smf.ols(formula='RIDERS ~ \
              SERVMILES_E_BART \
              + TOTEMP \
              + POP \
              + CASH_FARE_2010USD_BART \
              + FUEL_COST_2010USD \
              + BART_STRIKE \
              - 1', 
              data=diff2[13:])
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     125.8
# Date:                Tue, 11 Apr 2017   Prob (F-statistic):           9.68e-56
# Time:                        13:44:01   Log-Likelihood:                -1592.1
# No. Observations:                 155   AIC:                             3196.
# Df Residuals:                     149   BIC:                             3214.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# SERVMILES_E_BART           0.5337      1.438      0.371      0.711      -2.307       3.374
# TOTEMP                     0.1430      0.056      2.573      0.011       0.033       0.253
# POP                        0.2528      0.179      1.412      0.160      -0.101       0.607
# CASH_FARE_2010USD_BART -1.714e+04   1.13e+04     -1.511      0.133   -3.96e+04    5275.604
# FUEL_COST_2010USD       5.707e+04   5.23e+04      1.091      0.277   -4.63e+04     1.6e+05
# BART_STRIKE            -6.905e+04   2533.578    -27.252      0.000   -7.41e+04    -6.4e+04
# ==============================================================================
# Omnibus:                        2.086   Durbin-Watson:                   2.605
# Prob(Omnibus):                  0.352   Jarque-Bera (JB):                1.578
# Skew:                           0.003   Prob(JB):                        0.454
# Kurtosis:                       2.506   Cond. No.                     9.66e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.66e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# what if now drop the insignificant terms? 

mod = smf.ols(formula='RIDERS ~ \
              + TOTEMP \
              + BART_STRIKE \
              - 1', 
              data=diff2[13:])
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     367.3
# Date:                Tue, 11 Apr 2017   Prob (F-statistic):           3.93e-59
# Time:                        13:44:19   Log-Likelihood:                -1595.5
# No. Observations:                 155   AIC:                             3195.
# Df Residuals:                     153   BIC:                             3201.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# TOTEMP          0.1645      0.055      2.998      0.003       0.056       0.273
# BART_STRIKE -6.906e+04   2550.326    -27.077      0.000   -7.41e+04    -6.4e+04
# ==============================================================================
# Omnibus:                        3.491   Durbin-Watson:                   2.547
# Prob(Omnibus):                  0.175   Jarque-Bera (JB):                2.219
# Skew:                           0.043   Prob(JB):                        0.330
# Kurtosis:                       2.420   Cond. No.                     4.66e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.66e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# The R-squared is almost as good, but we can't predict what will happen if we change one of the other variables.  Sometimes we want to leave in an insignificant variable for theoretical or policy-sensitive reasons.

# %%
# And what if we drop the BART_STRIKE variable

mod = smf.ols(formula='RIDERS ~ \
              + TOTEMP \
              - 1', 
              data=diff2[13:])
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.2332
# Date:                Tue, 11 Apr 2017   Prob (F-statistic):              0.630
# Time:                        13:45:19   Log-Likelihood:                -1731.7
# No. Observations:                 155   AIC:                             3465.
# Df Residuals:                     154   BIC:                             3468.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# TOTEMP         0.0634      0.131      0.483      0.630      -0.196       0.323
# ==============================================================================
# Omnibus:                       42.924   Durbin-Watson:                   2.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              859.456
# Skew:                          -0.046   Prob(JB):                    2.35e-187
# Kurtosis:                      14.536   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Wow, that's a lot different!  In this case, we've run into 'ommitted variable bias', where our coefficients are biased (and our model is lousy) because we're missing something important.  So what do we do?

# %% [markdown]
# ### Recommendations
#
# Our friends at Northwestern (my alma mater!) have some good recommendations for how to
# proceed with these issues.
#
# Model Specification: Choosing the Right Variables for the Right Hand Side
#
# https://www.kellogg.northwestern.edu/faculty/dranove/htm/dranove/coursepages/Mgmt%20469/choosing%20variables.pdf
#
# They suggest:
#
# 1) Always begin with a “core” set of predictors that have theoretical relevance, as well as any predictors whose effects you are specifically interested in. You may estimate a “quick and dirty” OLS model at this time.
#
# 2) Finalize model specification issues (e.g., log vs. linear – to be discussed in a later note)
#
# 3) Add additional predictors that you think might be relevant. You can add them one at a time or one “category” at a time (see next section). Check for the robustness of your initial findings.
#
# 4) When adding predictors, you should keep all the original predictors in the model, even if they were not significant. Remember, omitted variable bias can cause significant predictors to appear to be insignificant. By adding more variables, your key predictors may become significant.
#
# 5) At this point, you should know your robust findings. That is the main goal of your research.
#
# 6) If you insist on producing a “final model”, then you should remove those additional predictors that were not remotely significant.
#
#
# 7) You can also remove core predictors if they remain insignificant and you need degrees of freedom. If you are not taxed for degrees of freedom, you may want to keep your core variables, if only to paint the entire picture for your audience.

# %% [markdown]
# ### Homework
#
# 1. Read the model specification document referenced above. \
# 2. Given what you have learned today, develop a new BART ridership model.  Make that model an ARMA model with independent regressors.  Specify the regressors in a logical way, and make sure your data are stationary before you begin.  Justify your preferred model.

# %%
# start from the variables we think are important

mod = smf.ols(formula='RIDERS ~ \
              SERVMILES_E_BART \
              + WORKERS \
              + AVG_FARE_2010USD_BART \
              + FUEL_COST_2010USD \
              + BART_STRIKE \
              - 1', 
              data=diff2[13:])
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     146.8
# Date:                Wed, 12 Apr 2017   Prob (F-statistic):           6.29e-56
# Time:                        08:56:47   Log-Likelihood:                -1594.3
# No. Observations:                 155   AIC:                             3199.
# Df Residuals:                     150   BIC:                             3214.
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# SERVMILES_E_BART          0.1977      1.462      0.135      0.893      -2.692       3.087
# WORKERS                   0.3657      0.139      2.639      0.009       0.092       0.640
# AVG_FARE_2010USD_BART -5195.6758   1.09e+04     -0.475      0.635   -2.68e+04    1.64e+04
# FUEL_COST_2010USD      7.162e+04   5.25e+04      1.365      0.174   -3.21e+04    1.75e+05
# BART_STRIKE            -6.88e+04   2604.161    -26.418      0.000   -7.39e+04   -6.37e+04
# ==============================================================================
# Omnibus:                        2.069   Durbin-Watson:                   2.620
# Prob(Omnibus):                  0.355   Jarque-Bera (JB):                1.602
# Skew:                           0.053   Prob(JB):                        0.449
# Kurtosis:                       2.513   Cond. No.                     3.87e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.87e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#SERVMILES is effectivle zero because of the large P-Value so I shall drop it from the model:

mod = smf.ols(formula='RIDERS ~ \
              + WORKERS \
              + AVG_FARE_2010USD_BART \
              + FUEL_COST_2010USD \
              + BART_STRIKE \
              - 1', 
              data=diff2[13:])
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     184.7
# Date:                Wed, 12 Apr 2017   Prob (F-statistic):           4.38e-57
# Time:                        08:58:41   Log-Likelihood:                -1594.3
# No. Observations:                 155   AIC:                             3197.
# Df Residuals:                     151   BIC:                             3209.
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# WORKERS                   0.3674      0.138      2.671      0.008       0.096       0.639
# AVG_FARE_2010USD_BART -4947.6873   1.07e+04     -0.460      0.646   -2.62e+04    1.63e+04
# FUEL_COST_2010USD      7.164e+04   5.23e+04      1.370      0.173   -3.17e+04    1.75e+05
# BART_STRIKE           -6.877e+04   2587.194    -26.581      0.000   -7.39e+04   -6.37e+04
# ==============================================================================
# Omnibus:                        2.039   Durbin-Watson:                   2.617
# Prob(Omnibus):                  0.361   Jarque-Bera (JB):                1.589
# Skew:                           0.054   Prob(JB):                        0.452
# Kurtosis:                       2.516   Cond. No.                     3.87e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.87e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#AVG fare isn't significant, but economically speaking, this should have an effect on ridership because
#this affects people's wallets which affects their decisions:
#Let's put this in a seasonal ARIMA model to see the effects:

# %%
diff = bart - bart.shift(12)
diff2 = diff - diff.shift(1)
diff2['RIDERS'].plot()

#Riders after seasonal adjustment:

# %%
fig1 = sm.graphics.tsa.plot_acf(diff2['WORKERS'][13:], lags=30)
fig2 = sm.graphics.tsa.plot_acf(diff2['AVG_FARE_2010USD_BART'][13:], lags=30)
fig3 = sm.graphics.tsa.plot_acf(diff2['FUEL_COST_2010USD'][13:], lags=30)
fig4 = sm.graphics.tsa.plot_acf(diff2['BART_STRIKE'][13:], lags=30)

# %%
#There still seems to be some fluctuation in the workers variable and the BART strike variable.
#Workers will most likely mess with the model after the fact, so lets see what removing the workers variable does:

mod = smf.ols(formula='RIDERS ~ \
              + AVG_FARE_2010USD_BART \
              + FUEL_COST_2010USD \
              + BART_STRIKE \
              - 1', 
              data=diff2[13:])
res = mod.fit()
print(res.summary())

#Variance explanation weht down, but the model benefits because of the lack of autocorrelation the workers variable was introducing despite the adjustments.
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 RIDERS   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     234.5
# Date:                Wed, 12 Apr 2017   Prob (F-statistic):           8.48e-57
# Time:                        09:09:26   Log-Likelihood:                -1597.9
# No. Observations:                 155   AIC:                             3202.
# Df Residuals:                     152   BIC:                             3211.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# AVG_FARE_2010USD_BART -5820.0639    1.1e+04     -0.531      0.596   -2.75e+04    1.58e+04
# FUEL_COST_2010USD      9.515e+04   5.26e+04      1.809      0.072   -8762.018    1.99e+05
# BART_STRIKE           -6.888e+04   2638.560    -26.103      0.000   -7.41e+04   -6.37e+04
# ==============================================================================
# Omnibus:                        2.315   Durbin-Watson:                   2.561
# Prob(Omnibus):                  0.314   Jarque-Bera (JB):                1.694
# Skew:                          -0.024   Prob(JB):                        0.429
# Kurtosis:                       2.490   Cond. No.                         20.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Time to fit a seasonal arima:
    
sm.tsa.SARIMAX?

# %%
Fare = sm.tsa.SARIMAX(bart['RIDERS'], bart['AVG_FARE_2010USD_BART'], (1,1,1),(1,1,1,12))
res = Fare.fit()
print(res.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             RIDERS   No. Observations:                  168
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -1699.151
# Date:                            Wed, 12 Apr 2017   AIC                           3410.301
# Time:                                    09:24:17   BIC                           3429.045
# Sample:                                01-01-2001   HQIC                          3417.908
#                                      - 12-01-2014
# Covariance Type:                              opg
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# AVG_FARE_2010USD_BART  4.228e+04    1.1e+04      3.842      0.000    2.07e+04    6.38e+04
# ar.L1                     0.0488      0.309      0.158      0.875      -0.557       0.654
# ma.L1                    -0.2672      0.302     -0.886      0.376      -0.858       0.324
# ar.S.L12                  0.2732      0.066      4.113      0.000       0.143       0.403
# ma.S.L12                 -0.7856      0.081     -9.700      0.000      -0.944      -0.627
# sigma2                 2.246e+08      5.935   3.78e+07      0.000    2.25e+08    2.25e+08
# ===================================================================================
# Ljung-Box (Q):                       63.58   Jarque-Bera (JB):               415.01
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.73   Skew:                            -0.75
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.11e+25. Standard errors may be unstable.

# %%
Fuel = sm.tsa.SARIMAX(bart['RIDERS'], bart['FUEL_COST_2010USD'], (1,1,1),(1,1,1,12))
res = Fuel.fit()
print(res.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             RIDERS   No. Observations:                  168
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -1707.594
# Date:                            Wed, 12 Apr 2017   AIC                           3427.189
# Time:                                    09:24:43   BIC                           3445.933
# Sample:                                01-01-2001   HQIC                          3434.796
#                                      - 12-01-2014
# Covariance Type:                              opg
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# FUEL_COST_2010USD  7.999e+04    1.6e+05      0.500      0.617   -2.33e+05    3.93e+05
# ar.L1                 0.0323      0.365      0.089      0.929      -0.682       0.747
# ma.L1                -0.1778      0.356     -0.499      0.618      -0.876       0.521
# ar.S.L12              0.4268      0.053      8.102      0.000       0.324       0.530
# ma.S.L12             -0.8323      0.069    -12.139      0.000      -0.967      -0.698
# sigma2               2.2e+08    484.003   4.55e+05      0.000     2.2e+08     2.2e+08
# ===================================================================================
# Ljung-Box (Q):                       83.54   Jarque-Bera (JB):               566.53
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.79   Skew:                            -0.63
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.39e+20. Standard errors may be unstable.

# %%
Strike = sm.tsa.SARIMAX(bart['RIDERS'], bart['BART_STRIKE'], (1,1,1),(1,1,1,12))
res = Strike.fit()
print(res.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             RIDERS   No. Observations:                  168
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -1593.219
# Date:                            Wed, 12 Apr 2017   AIC                           3198.437
# Time:                                    09:24:41   BIC                           3217.181
# Sample:                                01-01-2001   HQIC                          3206.045
#                                      - 12-01-2014
# Covariance Type:                              opg
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# BART_STRIKE -6.854e+04   2500.992    -27.403      0.000   -7.34e+04   -6.36e+04
# ar.L1          -0.7595      0.317     -2.398      0.016      -1.380      -0.139
# ma.L1           0.7369      0.321      2.296      0.022       0.108       1.366
# ar.S.L12        0.7891      0.066     11.957      0.000       0.660       0.918
# ma.S.L12       -0.9680      0.171     -5.677      0.000      -1.302      -0.634
# sigma2       4.988e+07      0.041   1.22e+09      0.000    4.99e+07    4.99e+07
# ===================================================================================
# Ljung-Box (Q):                       58.73   Jarque-Bera (JB):                 1.32
# Prob(Q):                              0.03   Prob(JB):                         0.52
# Heteroskedasticity (H):               1.00   Skew:                            -0.07
# Prob(H) (two-sided):                  0.99   Kurtosis:                         2.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.14e+26. Standard errors may be unstable.

# %%
#I am going to need some help interpreting these results.
